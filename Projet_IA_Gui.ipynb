# %%
import os
from cmath import rect, phase
from math import radians, degrees
import functools
import operator
import glob
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

from pandas import DataFrame, Series
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics

#import scikitplot
#from scikitplot.metrics import plot_roc_curve as prc
#from scikitplot.metrics import plot_lift_curve as plc
#from scikitplot.metrics import plot_cumulative_gain as pcg
#from sklearn.metrics import classification_report

# Ignore useless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
path = 'C:/Users/quent/OneDrive/Documents/GitHub/projet-ia/'

general = pd.read_csv(path + "general_data.csv")
employe = pd.read_csv(path + "employee_survey_data.csv")
manager = pd.read_csv(path + "manager_survey_data.csv")
In = pd.read_csv(path + "in_time.csv")
Out = pd.read_csv(path + "out_time.csv")

# %% [markdown]
# On remplace les "NaN" en 0 dans les tables In et Out, représentant les nombres de congés des employés. On vérifie ensuite que le nombre de congés dans les tables soient correct

# %%
In.fillna(0, inplace=True)
Out.fillna(0, inplace=True)
vac_In = (In == 0).astype(int).sum(axis=1)
vac_Out = (Out ==0).astype(int).sum(axis=1)
 
vac_In.equals(vac_Out)
# Out:
# True

# %% [markdown]
# On fait ensuite un graphe pour voir les jours de congés dans leur globalité

# %%
vac_In.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# On supprimes la première colonne des deux tableaux car elles ne sont pas utiles.

# %%
In = In.drop(In.columns[0], axis = 1)
Out = Out.drop(Out.columns[0], axis = 1)

# %% [markdown]
# On transforme les donnés des deux tables en format datetime pour pouvoir calculer plus facilement l'heure moyenne d'entrée et de sortie des employées

# %%
In_h = In.iloc[:, 0:262].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S' )
Out_h = Out.iloc[:, 0:262].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S' )

# %% [markdown]
# Nous réalisons à travers une fonction, le calcule de l'heure moyenne d'entré et de sortie de chaque employé :

# %%
def mean_angle(deg):
    return degrees(phase(sum(rect(1, radians(d)) for d in deg)/len(deg)))

def mean_time(row):
    t = ([time.hour, time.minute, time.second] for time in row)
    seconds = ((float(s) + int(m) * 60 + int(h) * 3600) 
               for h, m, s in t)
    seconds = [i for i in seconds if i > 0]
    day = 24 * 60 * 60
    to_angles = [s * 360. / day for s in seconds]
    mean_as_angle = mean_angle(to_angles)
    mean_seconds = mean_as_angle * day / 360.
    if mean_seconds < 0:
        mean_seconds += day
    h, m = divmod(mean_seconds, 3600)
    m, s = divmod(m, 60)
    return '%02i:%02i:%02i' % (h, m, s)

In_h['AverageInTime'] = In_h.apply(mean_time, axis=1)
Out_h['AverageInTime'] = Out_h.apply(mean_time, axis=1)

# %%
In_h['AverageInTime'].head()
# Out:
# 0    10:00:05
# 1    09:59:17
# 2    10:01:30
# 3    09:58:54
# 4    09:59:54
# Name: AverageInTime, dtype: object

# %% [markdown]
# Ensuite on calcule l'heure en moyen de travail en soustraitant la moyen de départ à la moyen d'arrivée grâce à Timedelta

# %%
Average_Out = pd.to_timedelta(Out_h['AverageInTime'])
Average_In = pd.to_timedelta(In_h['AverageInTime'])

AverageTimeWorking = Average_Out - Average_In

print(AverageTimeWorking)
# Out:
# 0      07:22:25
# 1      07:43:08
# 2      07:00:47
# 3      07:11:37
# 4      08:00:21
#          ...
# 4405   08:31:20
# 4406   06:05:34
# 4407   07:42:24
# 4408   09:29:34
# 4409   06:59:20
# Name: AverageInTime, Length: 4410, dtype: timedelta64[ns]

# %% [markdown]
# Il ne nous reste plus qu'a ajouter le nombre de vacances et l'heure de travail moyenne de chaque employés pour étudier leur cas.

# %%
#AverageTimeWorking.hist(bins=50, figsize=(20,15))
#ts = combined_csv['AverageTimeWorking'].astype(np.int64)
combined_csv['date_int'] = combined_csv.AverageTimeWorking.dt.hours
combined_csv['date_int']
#print(combined_csv.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-7588bd64632a> in <module>
#       1 #AverageTimeWorking.hist(bins=50, figsize=(20,15))
#       2 #ts = combined_csv['AverageTimeWorking'].astype(np.int64)
# ----> 3 combined_csv['date_int'] = combined_csv.AverageTimeWorking.dt.hours
#       4 combined_csv['date_int']
#       5 #print(combined_csv.dtypes)
#
# AttributeError: 'TimedeltaProperties' object has no attribute 'hours'

# %% [markdown]
# On fusionne les trois tableaux CSV pour regrouper les données :

# %%
combined = general.merge(manager, how='right', on = 'EmployeeID')
combined_csv = combined.merge(employe, how='right', on = 'EmployeeID')
#On transforme tous les NA en 0
combined_csv.fillna(0, inplace=True)
combined_csv['AverageTimeWorking'] = AverageTimeWorking
combined_csv['Holidays'] = vac_In

combined_csv
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# 1                   10          1  Life Sciences              1           2
# 2                   17          4          Other              1           3
# 3                    2          5  Life Sciences              1           4
# 4                   10          1        Medical              1           5
# ...                ...        ...            ...            ...         ...
# 4405                 5          4        Medical              1        4406
# 4406                 2          4        Medical              1        4407
# 4407                25          2  Life Sciences              1        4408
# 4408                18          2        Medical              1        4409
# 4409                28          3        Medical              1        4410
#
#       Gender  ...  YearsAtCompany YearsSinceLastPromotion  \
# 0     Female  ...               1                       0
# 1     Female  ...               5                       1
# 2       Male  ...               5                       0
# 3       Male  ...               8                       7
# 4       Male  ...               6                       0
# ...      ...  ...             ...                     ...
# 4405  Female  ...               3                       0
# 4406    Male  ...               3                       0
# 4407    Male  ...               4                       1
# 4408    Male  ...               9                       7
# 4409    Male  ...              21                       3
#
#      YearsWithCurrManager  JobInvolvement  PerformanceRating  \
# 0                       0               3                  3
# 1                       4               2                  4
# 2                       3               3                  3
# 3                       5               2                  3
# 4                       4               3                  3
# ...                   ...             ...                ...
# 4405                    2               3                  3
# 4406                    2               2                  3
# 4407                    2               3                  4
# 4408                    8               2                  3
# 4409                    9               4                  3
#
#      EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0                        3.0              4.0              2.0
# 1                        3.0              2.0              4.0
# 2                        2.0              2.0              1.0
# 3                        4.0              4.0              3.0
# 4                        4.0              1.0              3.0
# ...                      ...              ...              ...
# 4405                     4.0              1.0              3.0
# 4406                     4.0              4.0              3.0
# 4407                     1.0              3.0              3.0
# 4408                     4.0              1.0              3.0
# 4409                     1.0              3.0              0.0
#
#       AverageTimeWorking  Holidays
# 0               07:22:25        29
# 1               07:43:08        25
# 2               07:00:47        19
# 3               07:11:37        26
# 4               08:00:21        16
# ...                  ...       ...
# 4405            08:31:20        18
# 4406            06:05:34        20
# 4407            07:42:24        30
# 4408            09:29:34        20
# 4409            06:59:20        29
#
# [4410 rows x 31 columns]

# %%
combined_csv.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# 0                1.0                     6              1
# 1                6.0                     3              5
# 2                5.0                     2              5
# 3               13.0                     5              8
# 4                9.0                     2              6
#
#    YearsSinceLastPromotion  YearsWithCurrManager JobInvolvement  \
# 0                        0                     0              3
# 1                        1                     4              2
# 2                        0                     3              3
# 3                        7                     5              2
# 4                        0                     4              3
#
#    PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 0                  3                      3.0              4.0
# 1                  4                      3.0              2.0
# 2                  3                      2.0              2.0
# 3                  3                      4.0              4.0
# 4                  3                      4.0              1.0
#
#    WorkLifeBalance
# 0              2.0
# 1              4.0
# 2              1.0
# 3              3.0
# 4              3.0
#
# [5 rows x 29 columns]

# %%
combined_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 0 to 4409
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
#  14  NumCompaniesWorked       4410 non-null   float64
#  15  Over18                   4410 non-null   object
#  16  PercentSalaryHike        4410 non-null   int64
#  17  StandardHours            4410 non-null   int64
#  18  StockOptionLevel         4410 non-null   int64
#  19  TotalWorkingYears        4410 non-null   float64
#  20  TrainingTimesLastYear    4410 non-null   int64
#  21  YearsAtCompany           4410 non-null   int64
#  22  YearsSinceLastPromotion  4410 non-null   int64
#  23  YearsWithCurrManager     4410 non-null   int64
#  24  JobInvolvement           4410 non-null   int64
#  25  PerformanceRating        4410 non-null   int64
#  26  EnvironmentSatisfaction  4410 non-null   float64
#  27  JobSatisfaction          4410 non-null   float64
#  28  WorkLifeBalance          4410 non-null   float64
#  29  AverageTimeWorking       4410 non-null   timedelta64[ns]
#  30  Holidays                 4410 non-null   int64
# dtypes: float64(5), int64(17), object(8), timedelta64[ns](1)
# memory usage: 1.1+ MB

# %%
combined_csv.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# JobInvolvement             0
# PerformanceRating          0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# AverageTimeWorking         0
# Holidays                   0
# dtype: int64

# %%
combined_csv.astype(bool).sum(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a6ba7c227a05> in <module>
# ----> 1 combined_csv.astype(bool).sum(axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     861             return arr.astype(_TD_DTYPE, copy=copy)
#     862
# --> 863         raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     864
#     865     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
#
# TypeError: cannot astype a timedelta from [timedelta64[ns]] to [bool]

# %%
combined_csv['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
combined_csv['EmployeeCount'].value_counts()
# Out:
# 1    4410
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# Ils sont tous à 1 donc osef

# %% [markdown]
# Après concertation, nous avons décidé de supprimer les données Over18 et EmployeeCount.

# %%
combined_csv = combined_csv.drop(columns=['EmployeeCount','Over18'])

# %% [markdown]
# Attrition : yes -> l'employé est parti en 2016 / no -> il est toujours dans l'entreprise

# %%
combined_csv['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %% [markdown]
# On cherche à savoir pourquoi ces 711 employés ont quitté l'entreprise, nous allons donc uniquement nous concentrer sur les données où l'Attrition est 'yes'.

# %% [markdown]
# Pour commencer notre étude, nous allons nous interesser uniquement aux données liées aux employés qui ont quitté la structure, c'est-à-dire dont l'Attrition est 'yes'.

# %%
combinedLeft = combined_csv.drop(combined_csv[combined_csv.Attrition == 'No'].index).copy()
combinedLeft
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 1                   10          1  Life Sciences           2  Female
# 6                   11          2        Medical           7    Male
# 13                   1          1        Medical          14    Male
# 28                   1          2        Medical          29    Male
# 30                   4          3        Medical          31    Male
# ...                ...        ...            ...         ...     ...
# 4381                 7          1  Life Sciences        4382  Female
# 4386                11          4      Marketing        4387    Male
# 4388                 1          3  Life Sciences        4389    Male
# 4391                23          1  Life Sciences        4392    Male
# 4402                 2          3      Marketing        4403    Male
#
#       JobLevel  ... YearsAtCompany YearsSinceLastPromotion  \
# 1            1  ...              5                       1
# 6            2  ...              0                       0
# 13           1  ...             10                       9
# 28           2  ...              1                       0
# 30           3  ...              3                       0
# ...        ...  ...            ...                     ...
# 4381         1  ...              4                       0
# 4386         1  ...              5                       0
# 4388         2  ...              9                       1
# 4391         3  ...              3                       1
# 4402         1  ...              1                       0
#
#       YearsWithCurrManager  JobInvolvement  PerformanceRating  \
# 1                        4               2                  4
# 6                        0               3                  4
# 13                       9               2                  3
# 28                       0               2                  3
# 30                       2               2                  3
# ...                    ...             ...                ...
# 4381                     1               3                  4
# 4386                     4               2                  4
# 4388                     7               3                  3
# 4391                     2               3                  3
# 4402                     0               3                  3
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 1                         3.0              2.0              4.0
# 6                         1.0              3.0              1.0
# 13                        1.0              2.0              2.0
# 28                        4.0              3.0              1.0
# 30                        1.0              2.0              3.0
# ...                       ...              ...              ...
# 4381                      3.0              4.0              2.0
# 4386                      3.0              4.0              1.0
# 4388                      1.0              1.0              4.0
# 4391                      4.0              3.0              1.0
# 4402                      1.0              3.0              3.0
#
#       AverageTimeWorking  Holidays
# 1               07:43:08        25
# 6               06:55:25        29
# 13              09:24:00        26
# 28              10:58:40        18
# 30              10:06:34        23
# ...                  ...       ...
# 4381            08:24:24        22
# 4386            10:54:55        28
# 4388            07:05:49        31
# 4391            10:10:35        21
# 4402            07:06:42        23
#
# [711 rows x 29 columns]

# %%
combinedStay = combined_csv.drop(combined_csv[combined_csv.Attrition == 'Yes'].index).copy()
combinedStay
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# 2                   17          4          Other           3    Male
# 3                    2          5  Life Sciences           4    Male
# 4                   10          1        Medical           5    Male
# 5                    8          3  Life Sciences           6  Female
# ...                ...        ...            ...         ...     ...
# 4405                 5          4        Medical        4406  Female
# 4406                 2          4        Medical        4407    Male
# 4407                25          2  Life Sciences        4408    Male
# 4408                18          2        Medical        4409    Male
# 4409                28          3        Medical        4410    Male
#
#       JobLevel  ... YearsAtCompany YearsSinceLastPromotion  \
# 0            1  ...              1                       0
# 2            4  ...              5                       0
# 3            3  ...              8                       7
# 4            1  ...              6                       0
# 5            4  ...              7                       7
# ...        ...  ...            ...                     ...
# 4405         1  ...              3                       0
# 4406         1  ...              3                       0
# 4407         2  ...              4                       1
# 4408         1  ...              9                       7
# 4409         2  ...             21                       3
#
#       YearsWithCurrManager  JobInvolvement  PerformanceRating  \
# 0                        0               3                  3
# 2                        3               3                  3
# 3                        5               2                  3
# 4                        4               3                  3
# 5                        7               3                  3
# ...                    ...             ...                ...
# 4405                     2               3                  3
# 4406                     2               2                  3
# 4407                     2               3                  4
# 4408                     8               2                  3
# 4409                     9               4                  3
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0                         3.0              4.0              2.0
# 2                         2.0              2.0              1.0
# 3                         4.0              4.0              3.0
# 4                         4.0              1.0              3.0
# 5                         3.0              2.0              2.0
# ...                       ...              ...              ...
# 4405                      4.0              1.0              3.0
# 4406                      4.0              4.0              3.0
# 4407                      1.0              3.0              3.0
# 4408                      4.0              1.0              3.0
# 4409                      1.0              3.0              0.0
#
#       AverageTimeWorking  Holidays
# 0               07:22:25        29
# 2               07:00:47        19
# 3               07:11:37        26
# 4               08:00:21        16
# 5               10:47:46        24
# ...                  ...       ...
# 4405            08:31:20        18
# 4406            06:05:34        20
# 4407            07:42:24        30
# 4408            09:29:34        20
# 4409            06:59:20        29
#
# [3699 rows x 29 columns]

# %% [markdown]
# ## Étude des employés partis (Attrition = Yes)

# %% [markdown]
# Afin de pouvoir étudier d'éventuelles corrélations, nous allons, dans un DataFrame temporaire, numériser certaines valeurs afin de n'avoir que des valeurs numériques.

# %%
combinedLeft['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        468
# Travel_Frequently    207
# Non-Travel            36
# Name: BusinessTravel, dtype: int64

# %%
combinedLeft['Department'].value_counts()
# Out:
# Research & Development    453
# Sales                     201
# Human Resources            57
# Name: Department, dtype: int64

# %%
combinedLeft['EducationField'].value_counts()
# Out:
# Life Sciences       303
# Medical             225
# Marketing            75
# Technical Degree     45
# Human Resources      33
# Other                30
# Name: EducationField, dtype: int64

# %%
combinedLeft['JobRole'].value_counts()
# Out:
# Sales Executive              165
# Research Scientist           159
# Laboratory Technician        126
# Healthcare Representative     57
# Research Director             57
# Manufacturing Director        48
# Manager                       42
# Sales Representative          36
# Human Resources               21
# Name: JobRole, dtype: int64

# %%
combinedLeft['Gender'].value_counts()
# Out:
# Male      441
# Female    270
# Name: Gender, dtype: int64

# %%
combinedLeft['MaritalStatus'].value_counts()
# Out:
# Single      360
# Married     252
# Divorced     99
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# On initialise la copie du DataFrame.

# %%
combinedLeftNum = combinedLeft.copy()
combinedLeftNum
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 1                   10          1  Life Sciences           2  Female
# 6                   11          2        Medical           7    Male
# 13                   1          1        Medical          14    Male
# 28                   1          2        Medical          29    Male
# 30                   4          3        Medical          31    Male
# ...                ...        ...            ...         ...     ...
# 4381                 7          1  Life Sciences        4382  Female
# 4386                11          4      Marketing        4387    Male
# 4388                 1          3  Life Sciences        4389    Male
# 4391                23          1  Life Sciences        4392    Male
# 4402                 2          3      Marketing        4403    Male
#
#       JobLevel  ... YearsAtCompany YearsSinceLastPromotion  \
# 1            1  ...              5                       1
# 6            2  ...              0                       0
# 13           1  ...             10                       9
# 28           2  ...              1                       0
# 30           3  ...              3                       0
# ...        ...  ...            ...                     ...
# 4381         1  ...              4                       0
# 4386         1  ...              5                       0
# 4388         2  ...              9                       1
# 4391         3  ...              3                       1
# 4402         1  ...              1                       0
#
#       YearsWithCurrManager  JobInvolvement  PerformanceRating  \
# 1                        4               2                  4
# 6                        0               3                  4
# 13                       9               2                  3
# 28                       0               2                  3
# 30                       2               2                  3
# ...                    ...             ...                ...
# 4381                     1               3                  4
# 4386                     4               2                  4
# 4388                     7               3                  3
# 4391                     2               3                  3
# 4402                     0               3                  3
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 1                         3.0              2.0              4.0
# 6                         1.0              3.0              1.0
# 13                        1.0              2.0              2.0
# 28                        4.0              3.0              1.0
# 30                        1.0              2.0              3.0
# ...                       ...              ...              ...
# 4381                      3.0              4.0              2.0
# 4386                      3.0              4.0              1.0
# 4388                      1.0              1.0              4.0
# 4391                      4.0              3.0              1.0
# 4402                      1.0              3.0              3.0
#
#       AverageTimeWorking  Holidays
# 1               07:43:08        25
# 6               06:55:25        29
# 13              09:24:00        26
# 28              10:58:40        18
# 30              10:06:34        23
# ...                  ...       ...
# 4381            08:24:24        22
# 4386            10:54:55        28
# 4388            07:05:49        31
# 4391            10:10:35        21
# 4402            07:06:42        23
#
# [711 rows x 29 columns]

# %% [markdown]
# On reset l'index qui s'est retrouvé sans certains indices suite à notre supression de certaines données.

# %%
combinedLeftNum.reset_index(drop=True, inplace=True)
combinedLeftNum
# Out:
#      Age Attrition     BusinessTravel              Department  \
# 0     31       Yes  Travel_Frequently  Research & Development
# 1     28       Yes      Travel_Rarely  Research & Development
# 2     47       Yes         Non-Travel  Research & Development
# 3     44       Yes  Travel_Frequently  Research & Development
# 4     26       Yes      Travel_Rarely  Research & Development
# ..   ...       ...                ...                     ...
# 706   29       Yes      Travel_Rarely  Research & Development
# 707   33       Yes      Travel_Rarely                   Sales
# 708   33       Yes      Travel_Rarely                   Sales
# 709   32       Yes      Travel_Rarely                   Sales
# 710   37       Yes  Travel_Frequently                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeID  Gender  JobLevel  \
# 0                  10          1  Life Sciences           2  Female         1
# 1                  11          2        Medical           7    Male         2
# 2                   1          1        Medical          14    Male         1
# 3                   1          2        Medical          29    Male         2
# 4                   4          3        Medical          31    Male         3
# ..                ...        ...            ...         ...     ...       ...
# 706                 7          1  Life Sciences        4382  Female         1
# 707                11          4      Marketing        4387    Male         1
# 708                 1          3  Life Sciences        4389    Male         2
# 709                23          1  Life Sciences        4392    Male         3
# 710                 2          3      Marketing        4403    Male         1
#
#      ... YearsAtCompany YearsSinceLastPromotion  YearsWithCurrManager  \
# 0    ...              5                       1                     4
# 1    ...              0                       0                     0
# 2    ...             10                       9                     9
# 3    ...              1                       0                     0
# 4    ...              3                       0                     2
# ..   ...            ...                     ...                   ...
# 706  ...              4                       0                     1
# 707  ...              5                       0                     4
# 708  ...              9                       1                     7
# 709  ...              3                       1                     2
# 710  ...              1                       0                     0
#
#      JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0                 2                  4                      3.0
# 1                 3                  4                      1.0
# 2                 2                  3                      1.0
# 3                 2                  3                      4.0
# 4                 2                  3                      1.0
# ..              ...                ...                      ...
# 706               3                  4                      3.0
# 707               2                  4                      3.0
# 708               3                  3                      1.0
# 709               3                  3                      4.0
# 710               3                  3                      1.0
#
#      JobSatisfaction  WorkLifeBalance  AverageTimeWorking  Holidays
# 0                2.0              4.0            07:43:08        25
# 1                3.0              1.0            06:55:25        29
# 2                2.0              2.0            09:24:00        26
# 3                3.0              1.0            10:58:40        18
# 4                2.0              3.0            10:06:34        23
# ..               ...              ...                 ...       ...
# 706              4.0              2.0            08:24:24        22
# 707              4.0              1.0            10:54:55        28
# 708              1.0              4.0            07:05:49        31
# 709              3.0              1.0            10:10:35        21
# 710              3.0              3.0            07:06:42        23
#
# [711 rows x 29 columns]

# %% [markdown]
# Pour chaque donnée, on affecte une valeur numérique.

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['BusinessTravel'][i] == 'Non-Travel':
        combinedLeftNum['BusinessTravel'][i] = 0
    elif combinedLeftNum['BusinessTravel'][i] == 'Travel_Rarely':
        combinedLeftNum['BusinessTravel'][i] = 1
    elif combinedLeftNum['BusinessTravel'][i] == 'Travel_Frequently':
        combinedLeftNum['BusinessTravel'][i] = 2

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['Department'][i] == 'Human Resources':
        combinedLeftNum['Department'][i] = 0
    elif combinedLeftNum['Department'][i] == 'Sales':
        combinedLeftNum['Department'][i] = 1
    elif combinedLeftNum['Department'][i] == 'Research & Development':
        combinedLeftNum['Department'][i] = 2

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['EducationField'][i] == 'Other':
        combinedLeftNum['EducationField'][i] = 0
    elif combinedLeftNum['EducationField'][i] == 'Human Resources':
        combinedLeftNum['EducationField'][i] = 1
    elif combinedLeftNum['EducationField'][i] == 'Technical Degree':
        combinedLeftNum['EducationField'][i] = 2
    elif combinedLeftNum['EducationField'][i] == 'Marketing':
        combinedLeftNum['EducationField'][i] = 3
    elif combinedLeftNum['EducationField'][i] == 'Medical':
        combinedLeftNum['EducationField'][i] = 4
    elif combinedLeftNum['EducationField'][i] == 'Life Sciences':
        combinedLeftNum['EducationField'][i] = 5

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['JobRole'][i] == 'Human Resources':
        combinedLeftNum['JobRole'][i] = 0
    elif combinedLeftNum['JobRole'][i] == 'Sales Representative':
        combinedLeftNum['JobRole'][i] = 1
    elif combinedLeftNum['JobRole'][i] == 'Manager':
        combinedLeftNum['JobRole'][i] = 2
    elif combinedLeftNum['JobRole'][i] == 'Manufacturing Director':
        combinedLeftNum['JobRole'][i] = 3
    elif combinedLeftNum['JobRole'][i] == 'Healthcare Representative':
        combinedLeftNum['JobRole'][i] = 4
    elif combinedLeftNum['JobRole'][i] == 'Research Director':
        combinedLeftNum['JobRole'][i] = 5
    elif combinedLeftNum['JobRole'][i] == 'Laboratory Technician':
        combinedLeftNum['JobRole'][i] = 6
    elif combinedLeftNum['JobRole'][i] == 'Research Scientist':
        combinedLeftNum['JobRole'][i] = 7
    elif combinedLeftNum['JobRole'][i] == 'Sales Executive':
        combinedLeftNum['JobRole'][i] = 8

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['Gender'][i] == 'Male':
        combinedLeftNum['Gender'][i] = 0
    elif combinedLeftNum['Gender'][i] == 'Female':
        combinedLeftNum['Gender'][i] = 1

# %%
for i in range (0, combinedLeftNum.shape[0]):
    if combinedLeftNum['MaritalStatus'][i] == 'Single':
        combinedLeftNum['MaritalStatus'][i] = 0
    elif combinedLeftNum['MaritalStatus'][i] == 'Married':
        combinedLeftNum['MaritalStatus'][i] = 1
    elif combinedLeftNum['MaritalStatus'][i] == 'Divorced':
        combinedLeftNum['MaritalStatus'][i] = 2

# %% [markdown]
# On vérifie que tout a bien été numérisé.

# %%
combinedLeftNum
# Out:
#      Age Attrition BusinessTravel Department  DistanceFromHome  Education  \
# 0     31       Yes              2          2                10          1
# 1     28       Yes              1          2                11          2
# 2     47       Yes              0          2                 1          1
# 3     44       Yes              2          2                 1          2
# 4     26       Yes              1          2                 4          3
# ..   ...       ...            ...        ...               ...        ...
# 706   29       Yes              1          2                 7          1
# 707   33       Yes              1          1                11          4
# 708   33       Yes              1          1                 1          3
# 709   32       Yes              1          1                23          1
# 710   37       Yes              2          1                 2          3
#
#     EducationField  EmployeeID Gender  JobLevel  ... YearsAtCompany  \
# 0                5           2      1         1  ...              5
# 1                4           7      0         2  ...              0
# 2                4          14      0         1  ...             10
# 3                4          29      0         2  ...              1
# 4                4          31      0         3  ...              3
# ..             ...         ...    ...       ...  ...            ...
# 706              5        4382      1         1  ...              4
# 707              3        4387      0         1  ...              5
# 708              5        4389      0         2  ...              9
# 709              5        4392      0         3  ...              3
# 710              3        4403      0         1  ...              1
#
#     YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 0                         1                     4               2
# 1                         0                     0               3
# 2                         9                     9               2
# 3                         0                     0               2
# 4                         0                     2               2
# ..                      ...                   ...             ...
# 706                       0                     1               3
# 707                       0                     4               2
# 708                       1                     7               3
# 709                       1                     2               3
# 710                       0                     0               3
#
#      PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 0                    4                      3.0              2.0
# 1                    4                      1.0              3.0
# 2                    3                      1.0              2.0
# 3                    3                      4.0              3.0
# 4                    3                      1.0              2.0
# ..                 ...                      ...              ...
# 706                  4                      3.0              4.0
# 707                  4                      3.0              4.0
# 708                  3                      1.0              1.0
# 709                  3                      4.0              3.0
# 710                  3                      1.0              3.0
#
#      WorkLifeBalance  AverageTimeWorking  Holidays
# 0                4.0            07:43:08        25
# 1                1.0            06:55:25        29
# 2                2.0            09:24:00        26
# 3                1.0            10:58:40        18
# 4                3.0            10:06:34        23
# ..               ...                 ...       ...
# 706              2.0            08:24:24        22
# 707              1.0            10:54:55        28
# 708              4.0            07:05:49        31
# 709              1.0            10:10:35        21
# 710              3.0            07:06:42        23
#
# [711 rows x 29 columns]

# %%
# Les valeures numériques changées précédemment sont considérées comme des objets et non des valeures numériques
# On utilise to_numeric afin de changer cela et de pouvoir les visulaiser dans des tableaux/graphes.
combinedLeftNum['BusinessTravel']=pd.to_numeric(combinedLeftNum['BusinessTravel'])
combinedLeftNum['Department']=pd.to_numeric(combinedLeftNum['Department'])
combinedLeftNum['EducationField']=pd.to_numeric(combinedLeftNum['EducationField'])
combinedLeftNum['JobRole']=pd.to_numeric(combinedLeftNum['JobRole'])
combinedLeftNum['Gender']=pd.to_numeric(combinedLeftNum['Gender'])
combinedLeftNum['MaritalStatus']=pd.to_numeric(combinedLeftNum['MaritalStatus'])
print(combinedLeftNum.dtypes)
# Out:
# Age                                  int64
# Attrition                           object
# BusinessTravel                       int64
# Department                           int64
# DistanceFromHome                     int64
# Education                            int64
# EducationField                       int64
# EmployeeID                           int64
# Gender                               int64
# JobLevel                             int64
# JobRole                              int64
# MaritalStatus                        int64
# MonthlyIncome                        int64
# NumCompaniesWorked                 float64
# PercentSalaryHike                    int64
# StandardHours                        int64
# StockOptionLevel                     int64
# TotalWorkingYears                  float64
# TrainingTimesLastYear                int64
# YearsAtCompany                       int64
# YearsSinceLastPromotion              int64
# YearsWithCurrManager                 int64
# JobInvolvement                       int64
# PerformanceRating                    int64
# EnvironmentSatisfaction            float64
# JobSatisfaction                    float64
# WorkLifeBalance                    float64
# AverageTimeWorking         timedelta64[ns]
# Holidays                             int64
# dtype: object

# %% [markdown]
# Nous allons ensuite utiliser ces données numérisées afin de construire un tableau de corrélation, afin de voir si certaines données semblent plus ou moins correlées entre elles.

# %%
corr_cols = combinedLeftNum[['Age','BusinessTravel','Department','DistanceFromHome',
                     'Education','EducationField','EmployeeID', 'Gender', 'MaritalStatus',
                      'JobLevel',
                     'JobRole','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike',
                     'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear',
                     'YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager',
                     'JobInvolvement','PerformanceRating','EnvironmentSatisfaction',
                     'JobSatisfaction','WorkLifeBalance','AverageTimeWorking','Holidays']]
corr = corr_cols.corr()
plt.figure(figsize=(16,7))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# Nous pouvons constater que certaines données semblent liées fortement, notamment ce qui tourne autour de l'expérience de l'employé (Age, TotalWorkingYears, YearsAtCompany,YearsSinceLastPromotion, YearsWithCurrManager). On note également un lien entre le PerformanceRating et le PercentSalaryHike.

# %% [markdown]
# Faisons quelques graphes afin de voir si quoi que ce soit est notable visuellement.

# %%
combinedLeftNum.hist(bins=50, figsize=(20,15))
plt.show()

# %%
combinedLeft['Department'].value_counts()
# Out:
# Research & Development    453
# Sales                     201
# Human Resources            57
# Name: Department, dtype: int64

# %%
combinedLeftRes = combinedLeft[combinedLeft.Department == 'Research & Development'].copy()
combinedLeftRes
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4344   35       Yes      Travel_Rarely  Research & Development
# 4362   32       Yes      Travel_Rarely  Research & Development
# 4366   30       Yes      Travel_Rarely  Research & Development
# 4369   29       Yes      Travel_Rarely  Research & Development
# 4381   29       Yes      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 1                   10          1  Life Sciences           2  Female
# 6                   11          2        Medical           7    Male
# 13                   1          1        Medical          14    Male
# 28                   1          2        Medical          29    Male
# 30                   4          3        Medical          31    Male
# ...                ...        ...            ...         ...     ...
# 4344                 2          4  Life Sciences        4345  Female
# 4362                 5          3        Medical        4363    Male
# 4366                10          4  Life Sciences        4367  Female
# 4369                 2          3  Life Sciences        4370    Male
# 4381                 7          1  Life Sciences        4382  Female
#
#       JobLevel  ... TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 1            1  ...               6.0                     3               5
# 6            2  ...               5.0                     2               0
# 13           1  ...              10.0                     4              10
# 28           2  ...              19.0                     2               1
# 30           3  ...               5.0                     5               3
# ...        ...  ...               ...                   ...             ...
# 4344         2  ...               8.0                     3               1
# 4362         1  ...              14.0                     2              14
# 4366         2  ...               8.0                     3               5
# 4369         1  ...               7.0                     3               6
# 4381         1  ...               4.0                     2               4
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 1                           1                     4               2
# 6                           0                     0               3
# 13                          9                     9               2
# 28                          0                     0               2
# 30                          0                     2               2
# ...                       ...                   ...             ...
# 4344                        0                     1               4
# 4362                        9                     8               4
# 4366                        0                     4               2
# 4369                        1                     5               2
# 4381                        0                     1               3
#
#       PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 1                     4                      3.0              2.0
# 6                     4                      1.0              3.0
# 13                    3                      1.0              2.0
# 28                    3                      4.0              3.0
# 30                    3                      1.0              2.0
# ...                 ...                      ...              ...
# 4344                  3                      2.0              3.0
# 4362                  3                      4.0              4.0
# 4366                  3                      4.0              1.0
# 4369                  3                      3.0              3.0
# 4381                  4                      3.0              4.0
#
#       WorkLifeBalance
# 1                 4.0
# 6                 1.0
# 13                2.0
# 28                1.0
# 30                3.0
# ...               ...
# 4344              3.0
# 4362              2.0
# 4366              3.0
# 4369              2.0
# 4381              2.0
#
# [453 rows x 27 columns]

# %%
combinedLeftSales = combinedLeft[combinedLeft.Department == 'Sales'].copy()
combinedLeftSales
# Out:
#       Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 124    26       Yes  Travel_Frequently      Sales                14
# 127    30       Yes  Travel_Frequently      Sales                 3
# 178    33       Yes      Travel_Rarely      Sales                 5
# 182    34       Yes  Travel_Frequently      Sales                17
# 205    26       Yes      Travel_Rarely      Sales                 1
# ...   ...       ...                ...        ...               ...
# 4368   30       Yes  Travel_Frequently      Sales                 3
# 4386   33       Yes      Travel_Rarely      Sales                11
# 4388   33       Yes      Travel_Rarely      Sales                 1
# 4391   32       Yes      Travel_Rarely      Sales                23
# 4402   37       Yes  Travel_Frequently      Sales                 2
#
#       Education EducationField  EmployeeID  Gender  JobLevel  ...  \
# 124           3  Life Sciences         125    Male         2  ...
# 127           2      Marketing         128    Male         3  ...
# 178           4      Marketing         179    Male         2  ...
# 182           1      Marketing         183    Male         1  ...
# 205           3      Marketing         206  Female         2  ...
# ...         ...            ...         ...     ...       ...  ...
# 4368          2        Medical        4369    Male         2  ...
# 4386          4      Marketing        4387    Male         1  ...
# 4388          3  Life Sciences        4389    Male         2  ...
# 4391          1  Life Sciences        4392    Male         3  ...
# 4402          3      Marketing        4403    Male         1  ...
#
#      TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 124                7.0                     3               6
# 127                3.0                     2               1
# 178                8.0                     5               4
# 182               11.0                     5               3
# 205                1.0                     3               1
# ...                ...                   ...             ...
# 4368               9.0                     2               6
# 4386               8.0                     2               5
# 4388              13.0                     2               9
# 4391               4.0                     2               3
# 4402              17.0                     2               1
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 124                         0                     4               3
# 127                         0                     0               2
# 178                         1                     3               3
# 182                         0                     2               4
# 205                         0                     0               1
# ...                       ...                   ...             ...
# 4368                        0                     1               2
# 4386                        0                     4               2
# 4388                        1                     7               3
# 4391                        1                     2               3
# 4402                        0                     0               3
#
#       PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 124                   3                      3.0              0.0
# 127                   3                      3.0              4.0
# 178                   4                      1.0              4.0
# 182                   4                      2.0              1.0
# 205                   4                      3.0              4.0
# ...                 ...                      ...              ...
# 4368                  3                      3.0              1.0
# 4386                  4                      3.0              4.0
# 4388                  3                      1.0              1.0
# 4391                  3                      4.0              3.0
# 4402                  3                      1.0              3.0
#
#       WorkLifeBalance
# 124               3.0
# 127               3.0
# 178               3.0
# 182               3.0
# 205               1.0
# ...               ...
# 4368              2.0
# 4386              1.0
# 4388              4.0
# 4391              1.0
# 4402              3.0
#
# [201 rows x 27 columns]

# %%
combinedLeftHR = combinedLeft[combinedLeft.Department == 'Human Resources'].copy()
combinedLeftHR
# Out:
#       Age Attrition     BusinessTravel       Department  DistanceFromHome  \
# 105    33       Yes      Travel_Rarely  Human Resources                28
# 112    21       Yes      Travel_Rarely  Human Resources                10
# 310    55       Yes      Travel_Rarely  Human Resources                 7
# 350    55       Yes      Travel_Rarely  Human Resources                16
# 453    29       Yes      Travel_Rarely  Human Resources                 3
# 538    25       Yes      Travel_Rarely  Human Resources                25
# 599    44       Yes      Travel_Rarely  Human Resources                 6
# 613    24       Yes      Travel_Rarely  Human Resources                28
# 655    45       Yes      Travel_Rarely  Human Resources                12
# 878    28       Yes      Travel_Rarely  Human Resources                 1
# 943    23       Yes      Travel_Rarely  Human Resources                 6
# 999    31       Yes      Travel_Rarely  Human Resources                 9
# 1039   26       Yes      Travel_Rarely  Human Resources                 2
# 1096   56       Yes      Travel_Rarely  Human Resources                 1
# 1107   29       Yes  Travel_Frequently  Human Resources                 2
# 1245   39       Yes      Travel_Rarely  Human Resources                 1
# 1246   24       Yes      Travel_Rarely  Human Resources                 2
# 1312   37       Yes      Travel_Rarely  Human Resources                 9
# 1323   34       Yes  Travel_Frequently  Human Resources                 4
# 1575   33       Yes      Travel_Rarely  Human Resources                28
# 1582   21       Yes      Travel_Rarely  Human Resources                10
# 1780   55       Yes      Travel_Rarely  Human Resources                 7
# 1820   55       Yes      Travel_Rarely  Human Resources                16
# 1923   29       Yes      Travel_Rarely  Human Resources                 3
# 2008   25       Yes      Travel_Rarely  Human Resources                25
# 2069   44       Yes      Travel_Rarely  Human Resources                 6
# 2083   24       Yes      Travel_Rarely  Human Resources                28
# 2125   45       Yes      Travel_Rarely  Human Resources                12
# 2348   28       Yes      Travel_Rarely  Human Resources                 1
# 2413   23       Yes      Travel_Rarely  Human Resources                 6
# 2469   31       Yes      Travel_Rarely  Human Resources                 9
# 2509   26       Yes      Travel_Rarely  Human Resources                 2
# 2566   56       Yes      Travel_Rarely  Human Resources                 1
# 2577   29       Yes  Travel_Frequently  Human Resources                 2
# 2715   39       Yes      Travel_Rarely  Human Resources                 1
# 2716   24       Yes      Travel_Rarely  Human Resources                 2
# 2782   37       Yes      Travel_Rarely  Human Resources                 9
# 2793   34       Yes  Travel_Frequently  Human Resources                 4
# 3045   33       Yes      Travel_Rarely  Human Resources                28
# 3052   21       Yes      Travel_Rarely  Human Resources                10
# 3250   55       Yes      Travel_Rarely  Human Resources                 7
# 3290   55       Yes      Travel_Rarely  Human Resources                16
# 3393   29       Yes      Travel_Rarely  Human Resources                 3
# 3478   25       Yes      Travel_Rarely  Human Resources                25
# 3539   44       Yes      Travel_Rarely  Human Resources                 6
# 3553   24       Yes      Travel_Rarely  Human Resources                28
# 3595   45       Yes      Travel_Rarely  Human Resources                12
# 3818   28       Yes      Travel_Rarely  Human Resources                 1
# 3883   23       Yes      Travel_Rarely  Human Resources                 6
# 3939   31       Yes      Travel_Rarely  Human Resources                 9
# 3979   26       Yes      Travel_Rarely  Human Resources                 2
# 4036   56       Yes      Travel_Rarely  Human Resources                 1
# 4047   29       Yes  Travel_Frequently  Human Resources                 2
# 4185   39       Yes      Travel_Rarely  Human Resources                 1
# 4186   24       Yes      Travel_Rarely  Human Resources                 2
# 4252   37       Yes      Travel_Rarely  Human Resources                 9
# 4263   34       Yes  Travel_Frequently  Human Resources                 4
#
#       Education    EducationField  EmployeeID  Gender  JobLevel  ...  \
# 105           2   Human Resources         106  Female         5  ...
# 112           2   Human Resources         113    Male         1  ...
# 310           3   Human Resources         311    Male         4  ...
# 350           3  Technical Degree         351    Male         4  ...
# 453           5     Life Sciences         454    Male         1  ...
# 538           4   Human Resources         539  Female         2  ...
# 599           2   Human Resources         600    Male         3  ...
# 613           4   Human Resources         614    Male         3  ...
# 655           3   Human Resources         656    Male         2  ...
# 878           3           Medical         879  Female         2  ...
# 943           3     Life Sciences         944  Female         3  ...
# 999           4   Human Resources        1000    Male         2  ...
# 1039          1  Technical Degree        1040  Female         3  ...
# 1096          2           Medical        1097  Female         5  ...
# 1107          4   Human Resources        1108    Male         2  ...
# 1245          4           Medical        1246    Male         1  ...
# 1246          5   Human Resources        1247    Male         3  ...
# 1312          3   Human Resources        1313    Male         2  ...
# 1323          4     Life Sciences        1324  Female         5  ...
# 1575          2   Human Resources        1576  Female         5  ...
# 1582          2   Human Resources        1583    Male         1  ...
# 1780          3   Human Resources        1781    Male         4  ...
# 1820          3  Technical Degree        1821    Male         4  ...
# 1923          5     Life Sciences        1924    Male         1  ...
# 2008          4   Human Resources        2009  Female         2  ...
# 2069          2   Human Resources        2070    Male         3  ...
# 2083          4   Human Resources        2084    Male         3  ...
# 2125          3   Human Resources        2126    Male         2  ...
# 2348          3           Medical        2349  Female         2  ...
# 2413          3     Life Sciences        2414  Female         3  ...
# 2469          4   Human Resources        2470    Male         2  ...
# 2509          1  Technical Degree        2510  Female         3  ...
# 2566          2           Medical        2567  Female         5  ...
# 2577          4   Human Resources        2578    Male         2  ...
# 2715          4           Medical        2716    Male         1  ...
# 2716          5   Human Resources        2717    Male         3  ...
# 2782          3   Human Resources        2783    Male         2  ...
# 2793          4     Life Sciences        2794  Female         5  ...
# 3045          2   Human Resources        3046  Female         5  ...
# 3052          2   Human Resources        3053    Male         1  ...
# 3250          3   Human Resources        3251    Male         4  ...
# 3290          3  Technical Degree        3291    Male         4  ...
# 3393          5     Life Sciences        3394    Male         1  ...
# 3478          4   Human Resources        3479  Female         2  ...
# 3539          2   Human Resources        3540    Male         3  ...
# 3553          4   Human Resources        3554    Male         3  ...
# 3595          3   Human Resources        3596    Male         2  ...
# 3818          3           Medical        3819  Female         2  ...
# 3883          3     Life Sciences        3884  Female         3  ...
# 3939          4   Human Resources        3940    Male         2  ...
# 3979          1  Technical Degree        3980  Female         3  ...
# 4036          2           Medical        4037  Female         5  ...
# 4047          4   Human Resources        4048    Male         2  ...
# 4185          4           Medical        4186    Male         1  ...
# 4186          5   Human Resources        4187    Male         3  ...
# 4252          3   Human Resources        4253    Male         2  ...
# 4263          4     Life Sciences        4264  Female         5  ...
#
#      TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 105                1.0                     3               1
# 112                1.0                     2               1
# 310               24.0                     2               5
# 350               12.0                     3               9
# 453                3.0                     2               0
# 538                7.0                     3               7
# 599                6.0                     2               6
# 613                1.0                     5               1
# 655               26.0                     3              24
# 878                1.0                     2               1
# 943                5.0                     3               5
# 999               10.0                     2               1
# 1039               6.0                     3               5
# 1096               5.0                     3               4
# 1107               1.0                     3               1
# 1245              19.0                     3               1
# 1246               6.0                     2               2
# 1312               7.0                     4               3
# 1323               9.0                     3               9
# 1575               1.0                     3               1
# 1582               1.0                     2               1
# 1780              24.0                     2               5
# 1820              12.0                     3               9
# 1923               3.0                     2               0
# 2008               7.0                     3               7
# 2069               6.0                     2               6
# 2083               1.0                     5               1
# 2125              26.0                     3              24
# 2348               1.0                     2               1
# 2413               5.0                     3               5
# 2469              10.0                     2               1
# 2509               6.0                     3               5
# 2566               5.0                     3               4
# 2577               1.0                     3               1
# 2715              19.0                     3               1
# 2716               6.0                     2               2
# 2782               7.0                     4               3
# 2793               9.0                     3               9
# 3045               1.0                     3               1
# 3052               1.0                     2               1
# 3250              24.0                     2               5
# 3290              12.0                     3               9
# 3393               3.0                     2               0
# 3478               7.0                     3               7
# 3539               6.0                     2               6
# 3553               1.0                     5               1
# 3595              26.0                     3              24
# 3818               0.0                     2               1
# 3883               5.0                     3               5
# 3939              10.0                     2               1
# 3979               6.0                     3               5
# 4036               5.0                     3               4
# 4047               1.0                     3               1
# 4185              19.0                     3               1
# 4186               6.0                     2               2
# 4252               7.0                     4               3
# 4263               9.0                     3               9
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 105                         0                     0               1
# 112                         0                     0               3
# 310                         1                     4               3
# 350                         7                     3               4
# 453                         0                     0               2
# 538                         5                     6               2
# 599                         0                     2               1
# 613                         0                     0               3
# 655                         1                    11               3
# 878                         0                     0               3
# 943                         1                     2               3
# 999                         0                     0               3
# 1039                        1                     4               2
# 1096                        1                     0               3
# 1107                        0                     0               3
# 1245                        0                     0               3
# 1246                        2                     0               2
# 1312                        0                     2               3
# 1323                        0                     6               3
# 1575                        0                     0               1
# 1582                        0                     0               3
# 1780                        1                     4               3
# 1820                        7                     3               4
# 1923                        0                     0               2
# 2008                        5                     6               2
# 2069                        0                     2               1
# 2083                        0                     0               3
# 2125                        1                    11               3
# 2348                        0                     0               3
# 2413                        1                     2               3
# 2469                        0                     0               3
# 2509                        1                     4               2
# 2566                        1                     0               3
# 2577                        0                     0               3
# 2715                        0                     0               3
# 2716                        2                     0               2
# 2782                        0                     2               3
# 2793                        0                     6               3
# 3045                        0                     0               1
# 3052                        0                     0               3
# 3250                        1                     4               3
# 3290                        7                     3               4
# 3393                        0                     0               2
# 3478                        5                     6               2
# 3539                        0                     2               1
# 3553                        0                     0               3
# 3595                        1                    11               3
# 3818                        0                     0               3
# 3883                        1                     2               3
# 3939                        0                     0               3
# 3979                        1                     4               2
# 4036                        1                     0               3
# 4047                        0                     0               3
# 4185                        0                     0               3
# 4186                        2                     0               2
# 4252                        0                     2               3
# 4263                        0                     6               3
#
#       PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 105                   4                      4.0              3.0
# 112                   3                      3.0              2.0
# 310                   3                      4.0              1.0
# 350                   3                      3.0              4.0
# 453                   3                      4.0              1.0
# 538                   3                      4.0              4.0
# 599                   3                      3.0              3.0
# 613                   3                      4.0              2.0
# 655                   3                      1.0              2.0
# 878                   3                      3.0              2.0
# 943                   3                      4.0              3.0
# 999                   3                      1.0              3.0
# 1039                  3                      4.0              2.0
# 1096                  4                      1.0              4.0
# 1107                  3                      3.0              1.0
# 1245                  3                      4.0              4.0
# 1246                  3                      2.0              4.0
# 1312                  3                      3.0              1.0
# 1323                  3                      1.0              3.0
# 1575                  4                      4.0              3.0
# 1582                  3                      3.0              2.0
# 1780                  3                      4.0              1.0
# 1820                  3                      3.0              4.0
# 1923                  3                      4.0              1.0
# 2008                  3                      4.0              4.0
# 2069                  3                      3.0              3.0
# 2083                  3                      4.0              2.0
# 2125                  3                      1.0              2.0
# 2348                  3                      3.0              2.0
# 2413                  3                      4.0              3.0
# 2469                  3                      1.0              3.0
# 2509                  3                      4.0              2.0
# 2566                  4                      1.0              4.0
# 2577                  3                      3.0              1.0
# 2715                  3                      4.0              4.0
# 2716                  3                      2.0              4.0
# 2782                  3                      3.0              1.0
# 2793                  3                      1.0              3.0
# 3045                  4                      4.0              3.0
# 3052                  3                      3.0              2.0
# 3250                  3                      4.0              1.0
# 3290                  3                      3.0              4.0
# 3393                  3                      4.0              1.0
# 3478                  3                      4.0              4.0
# 3539                  3                      3.0              3.0
# 3553                  3                      4.0              2.0
# 3595                  3                      1.0              2.0
# 3818                  3                      3.0              2.0
# 3883                  3                      4.0              3.0
# 3939                  3                      1.0              3.0
# 3979                  3                      4.0              2.0
# 4036                  4                      1.0              4.0
# 4047                  3                      3.0              1.0
# 4185                  3                      4.0              4.0
# 4186                  3                      2.0              4.0
# 4252                  3                      3.0              1.0
# 4263                  3                      1.0              3.0
#
#       WorkLifeBalance
# 105               3.0
# 112               3.0
# 310               3.0
# 350               2.0
# 453               3.0
# 538               4.0
# 599               3.0
# 613               1.0
# 655               3.0
# 878               3.0
# 943               3.0
# 999               3.0
# 1039              3.0
# 1096              3.0
# 1107              3.0
# 1245              4.0
# 1246              2.0
# 1312              3.0
# 1323              0.0
# 1575              3.0
# 1582              3.0
# 1780              3.0
# 1820              2.0
# 1923              3.0
# 2008              4.0
# 2069              3.0
# 2083              1.0
# 2125              3.0
# 2348              3.0
# 2413              3.0
# 2469              3.0
# 2509              3.0
# 2566              3.0
# 2577              3.0
# 2715              4.0
# 2716              2.0
# 2782              3.0
# 2793              3.0
# 3045              3.0
# 3052              3.0
# 3250              3.0
# 3290              2.0
# 3393              3.0
# 3478              4.0
# 3539              3.0
# 3553              1.0
# 3595              3.0
# 3818              3.0
# 3883              3.0
# 3939              3.0
# 3979              3.0
# 4036              3.0
# 4047              3.0
# 4185              4.0
# 4186              2.0
# 4252              3.0
# 4263              3.0
#
# [57 rows x 27 columns]

# %% [markdown]
# Le nombre de départs d'employés travaillant aux Ressources Humaines ne représentant que 8.02% des départs, nous faisons le choix de les ignorer pour le moment.

# %% [markdown]
# ## Étude des départs depuis le département R&D

# %% [markdown]
# ### Comparaison en fonction du JobRole

# %% [markdown]
# Nous allons tenter de voir s'il y a une possible corrélation entre les départs liés au département R&D et le métier dans l'entreprise des employés.

# %%
combinedLeftRes['JobRole'].value_counts()
# Out:
# Sales Executive              111
# Research Scientist            99
# Laboratory Technician         72
# Research Director             42
# Manufacturing Director        36
# Sales Representative          30
# Manager                       24
# Healthcare Representative     21
# Human Resources               18
# Name: JobRole, dtype: int64

# %% [markdown]
# 24.5% des départs de ce département viennent des personnes travaillant en tant que Sales Executive.
# Les départs des Research Scientists représentent à eux 21.9% des départs.

# %%
combinedLeftRes.hist(bins=50, figsize=(20,15))
plt.show()

# %%
corr_cols = combinedLeftRes[['Age','BusinessTravel','Department','DistanceFromHome',
                     'Education','EducationField','EmployeeID', 'Gender', 'MaritalStatus',
                      'JobLevel',
                     'JobRole','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike',
                     'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear',
                     'YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager',
                     'JobInvolvement','PerformanceRating','EnvironmentSatisfaction',
                     'JobSatisfaction','WorkLifeBalance']]
corr = corr_cols.corr()
plt.figure(figsize=(16,7))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# # Étude des employés restés (Attrition = No)

# %% [markdown]
# Nous allons effectuer à nouveau les mêmes démarches qu'avec l'autre groupe.

# %%
combinedStayNum = combinedStay.copy()
combinedStayNum.reset_index(drop=True, inplace=True)
combinedStayNum
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      32        No  Travel_Frequently  Research & Development
# 2      38        No         Non-Travel  Research & Development
# 3      32        No      Travel_Rarely  Research & Development
# 4      46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 3694   42        No      Travel_Rarely  Research & Development
# 3695   29        No      Travel_Rarely  Research & Development
# 3696   25        No      Travel_Rarely  Research & Development
# 3697   42        No      Travel_Rarely                   Sales
# 3698   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# 1                   17          4          Other           3    Male
# 2                    2          5  Life Sciences           4    Male
# 3                   10          1        Medical           5    Male
# 4                    8          3  Life Sciences           6  Female
# ...                ...        ...            ...         ...     ...
# 3694                 5          4        Medical        4406  Female
# 3695                 2          4        Medical        4407    Male
# 3696                25          2  Life Sciences        4408    Male
# 3697                18          2        Medical        4409    Male
# 3698                28          3        Medical        4410    Male
#
#       JobLevel  ... TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 0            1  ...               1.0                     6               1
# 1            4  ...               5.0                     2               5
# 2            3  ...              13.0                     5               8
# 3            1  ...               9.0                     2               6
# 4            4  ...              28.0                     5               7
# ...        ...  ...               ...                   ...             ...
# 3694         1  ...              10.0                     5               3
# 3695         1  ...              10.0                     2               3
# 3696         2  ...               5.0                     4               4
# 3697         1  ...              10.0                     2               9
# 3698         2  ...               0.0                     6              21
#
#       YearsSinceLastPromotion  YearsWithCurrManager  JobInvolvement  \
# 0                           0                     0               3
# 1                           0                     3               3
# 2                           7                     5               2
# 3                           0                     4               3
# 4                           7                     7               3
# ...                       ...                   ...             ...
# 3694                        0                     2               3
# 3695                        0                     2               2
# 3696                        1                     2               3
# 3697                        7                     8               2
# 3698                        3                     9               4
#
#       PerformanceRating  EnvironmentSatisfaction  JobSatisfaction  \
# 0                     3                      3.0              4.0
# 1                     3                      2.0              2.0
# 2                     3                      4.0              4.0
# 3                     3                      4.0              1.0
# 4                     3                      3.0              2.0
# ...                 ...                      ...              ...
# 3694                  3                      4.0              1.0
# 3695                  3                      4.0              4.0
# 3696                  4                      1.0              3.0
# 3697                  3                      4.0              1.0
# 3698                  3                      1.0              3.0
#
#       WorkLifeBalance
# 0                 2.0
# 1                 1.0
# 2                 3.0
# 3                 3.0
# 4                 2.0
# ...               ...
# 3694              3.0
# 3695              3.0
# 3696              3.0
# 3697              3.0
# 3698              0.0
#
# [3699 rows x 27 columns]

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['BusinessTravel'][i] == 'Non-Travel':
        combinedStayNum['BusinessTravel'][i] = 0
    elif combinedStayNum['BusinessTravel'][i] == 'Travel_Rarely':
        combinedStayNum['BusinessTravel'][i] = 1
    elif combinedStayNum['BusinessTravel'][i] == 'Travel_Frequently':
        combinedStayNum['BusinessTravel'][i] = 2

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['Department'][i] == 'Human Resources':
        combinedStayNum['Department'][i] = 0
    elif combinedStayNum['Department'][i] == 'Sales':
        combinedStayNum['Department'][i] = 1
    elif combinedStayNum['Department'][i] == 'Research & Development':
        combinedStayNum['Department'][i] = 2

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['EducationField'][i] == 'Other':
        combinedStayNum['EducationField'][i] = 0
    elif combinedStayNum['EducationField'][i] == 'Human Resources':
        combinedStayNum['EducationField'][i] = 1
    elif combinedStayNum['EducationField'][i] == 'Technical Degree':
        combinedStayNum['EducationField'][i] = 2
    elif combinedStayNum['EducationField'][i] == 'Marketing':
        combinedStayNum['EducationField'][i] = 3
    elif combinedStayNum['EducationField'][i] == 'Medical':
        combinedStayNum['EducationField'][i] = 4
    elif combinedStayNum['EducationField'][i] == 'Life Sciences':
        combinedStayNum['EducationField'][i] = 5

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['JobRole'][i] == 'Human Resources':
        combinedStayNum['JobRole'][i] = 0
    elif combinedStayNum['JobRole'][i] == 'Sales Representative':
        combinedStayNum['JobRole'][i] = 1
    elif combinedStayNum['JobRole'][i] == 'Manager':
        combinedStayNum['JobRole'][i] = 2
    elif combinedStayNum['JobRole'][i] == 'Manufacturing Director':
        combinedStayNum['JobRole'][i] = 3
    elif combinedStayNum['JobRole'][i] == 'Healthcare Representative':
        combinedStayNum['JobRole'][i] = 4
    elif combinedStayNum['JobRole'][i] == 'Research Director':
        combinedStayNum['JobRole'][i] = 5
    elif combinedStayNum['JobRole'][i] == 'Laboratory Technician':
        combinedStayNum['JobRole'][i] = 6
    elif combinedStayNum['JobRole'][i] == 'Research Scientist':
        combinedStayNum['JobRole'][i] = 7
    elif combinedStayNum['JobRole'][i] == 'Sales Executive':
        combinedStayNum['JobRole'][i] = 8

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['Gender'][i] == 'Male':
        combinedStayNum['Gender'][i] = 0
    elif combinedStayNum['Gender'][i] == 'Female':
        combinedStayNum['Gender'][i] = 1

# %%
for i in range (0, combinedStayNum.shape[0]):
    if combinedStayNum['MaritalStatus'][i] == 'Single':
        combinedStayNum['MaritalStatus'][i] = 0
    elif combinedStayNum['MaritalStatus'][i] == 'Married':
        combinedStayNum['MaritalStatus'][i] = 1
    elif combinedStayNum['MaritalStatus'][i] == 'Divorced':
        combinedStayNum['MaritalStatus'][i] = 2

# %%
combinedStayNum
# Out:
#       Age Attrition BusinessTravel Department  DistanceFromHome  Education  \
# 0      51        No              1          1                 6          2
# 1      32        No              2          2                17          4
# 2      38        No              0          2                 2          5
# 3      32        No              1          2                10          1
# 4      46        No              1          2                 8          3
# ...   ...       ...            ...        ...               ...        ...
# 3694   42        No              1          2                 5          4
# 3695   29        No              1          2                 2          4
# 3696   25        No              1          2                25          2
# 3697   42        No              1          1                18          2
# 3698   40        No              1          2                28          3
#
#      EducationField  EmployeeID Gender  JobLevel  ... TotalWorkingYears  \
# 0                 5           1      1         1  ...               1.0
# 1                 0           3      0         4  ...               5.0
# 2                 5           4      0         3  ...              13.0
# 3                 4           5      0         1  ...               9.0
# 4                 5           6      1         4  ...              28.0
# ...             ...         ...    ...       ...  ...               ...
# 3694              4        4406      1         1  ...              10.0
# 3695              4        4407      0         1  ...              10.0
# 3696              5        4408      0         2  ...               5.0
# 3697              4        4409      0         1  ...              10.0
# 3698              4        4410      0         2  ...               0.0
#
#      TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                        6               1                        0
# 1                        2               5                        0
# 2                        5               8                        7
# 3                        2               6                        0
# 4                        5               7                        7
# ...                    ...             ...                      ...
# 3694                     5               3                        0
# 3695                     2               3                        0
# 3696                     4               4                        1
# 3697                     2               9                        7
# 3698                     6              21                        3
#
#       YearsWithCurrManager  JobInvolvement  PerformanceRating  \
# 0                        0               3                  3
# 1                        3               3                  3
# 2                        5               2                  3
# 3                        4               3                  3
# 4                        7               3                  3
# ...                    ...             ...                ...
# 3694                     2               3                  3
# 3695                     2               2                  3
# 3696                     2               3                  4
# 3697                     8               2                  3
# 3698                     9               4                  3
#
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0                         3.0              4.0              2.0
# 1                         2.0              2.0              1.0
# 2                         4.0              4.0              3.0
# 3                         4.0              1.0              3.0
# 4                         3.0              2.0              2.0
# ...                       ...              ...              ...
# 3694                      4.0              1.0              3.0
# 3695                      4.0              4.0              3.0
# 3696                      1.0              3.0              3.0
# 3697                      4.0              1.0              3.0
# 3698                      1.0              3.0              0.0
#
# [3699 rows x 27 columns]

# %%
# Les valeures numériques changées précédemment sont considérées comme des objets et non des valeures numériques
# On utilise to_numeric afin de changer cela et de pouvoir les visulaiser dans des tableaux/graphes.
combinedStayNum['BusinessTravel']=pd.to_numeric(combinedStayNum['BusinessTravel'])
combinedStayNum['Department']=pd.to_numeric(combinedStayNum['Department'])
combinedStayNum['EducationField']=pd.to_numeric(combinedStayNum['EducationField'])
combinedStayNum['JobRole']=pd.to_numeric(combinedStayNum['JobRole'])
combinedStayNum['Gender']=pd.to_numeric(combinedStayNum['Gender'])
combinedStayNum['MaritalStatus']=pd.to_numeric(combinedStayNum['MaritalStatus'])
print(combinedStayNum.dtypes)
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel               int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeID                   int64
# Gender                       int64
# JobLevel                     int64
# JobRole                      int64
# MaritalStatus                int64
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# JobInvolvement               int64
# PerformanceRating            int64
# EnvironmentSatisfaction    float64
# JobSatisfaction            float64
# WorkLifeBalance            float64
# dtype: object

# %%
corr_cols = combinedStayNum[['Age','BusinessTravel','Department','DistanceFromHome',
                     'Education','EducationField','EmployeeID', 'Gender', 'MaritalStatus',
                      'JobLevel',
                     'JobRole','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike',
                     'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear',
                     'YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager',
                     'JobInvolvement','PerformanceRating','EnvironmentSatisfaction',
                     'JobSatisfaction','WorkLifeBalance']]
corr = corr_cols.corr()
plt.figure(figsize=(16,7))
sns.heatmap(corr, annot=True)
plt.show()

# %%
combinedStayNum.hist(bins=50, figsize=(20,15))
plt.show()
